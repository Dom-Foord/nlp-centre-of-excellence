# %%
import pandas as pd
import numpy as np
import datetime
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df_BTC = pd.read_csv('BTC-all-data.csv')

# %%
df_BTC.head()
# Out:
#               open_time            close_time      open      high       low  \
# 0  05/24/2023, 23:00:00  05/24/2023, 23:59:59  26348.52  26394.16  26318.25
# 1  05/24/2023, 22:00:00  05/24/2023, 22:59:59  26368.66  26406.00  26313.47
# 2  05/24/2023, 21:00:00  05/24/2023, 21:59:59  26404.18  26464.65  26310.48
# 3  05/24/2023, 20:00:00  05/24/2023, 20:59:59  26252.34  26486.46  26242.62
# 4  05/24/2023, 19:00:00  05/24/2023, 19:59:59  26220.55  26397.64  26201.67
#
#       close      volume  quote_asset_volume  num_trades  \
# 0  26329.01   712.51394         18778933.16       16479
# 1  26348.52   746.24121         19670396.24       19907
# 2  26368.66  1223.45586         32298325.57       27225
# 3  26404.18  2878.77545         75937036.88       47336
# 4  26252.33  2349.96235         61795762.11       40509
#
#    taker_buy_base_asset_volume  taker_buy_quote_asset_volume  ignore  \
# 0                    376.83127                  9.932271e+06       0
# 1                    325.98884                  8.592227e+06       0
# 2                    642.68037                  1.696504e+07       0
# 3                   1539.53932                  4.060586e+07       0
# 4                   1171.28517                  3.080221e+07       0
#
#    open_timestamp  close_timestamp
# 0    1.684970e+12     1.684970e+12
# 1    1.684970e+12     1.684970e+12
# 2    1.684960e+12     1.684970e+12
# 3    1.684960e+12     1.684960e+12
# 4    1.684950e+12     1.684960e+12

# %%
df_BTC['open_time']
# Out:
# 0        05/24/2023, 23:00:00
# 1        05/24/2023, 22:00:00
# 2        05/24/2023, 21:00:00
# 3        05/24/2023, 20:00:00
# 4        05/24/2023, 19:00:00
#                  ...
# 20957    01/01/2021, 04:00:00
# 20958    01/01/2021, 03:00:00
# 20959    01/01/2021, 02:00:00
# 20960    01/01/2021, 01:00:00
# 20961    01/01/2021, 00:00:00
# Name: open_time, Length: 20962, dtype: object

# %%
df_BTC['datetime'] = df_BTC['open_time'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y, %H:%M:%S"))

# %%
df_BTC['year'] = df_BTC['datetime'].apply(lambda x: x.year)
df_BTC['month'] = df_BTC['datetime'].apply(lambda x: x.month)
df_BTC['day'] = df_BTC['datetime'].apply(lambda x: x.day)
df_BTC['day_of_week'] = df_BTC['datetime'].apply(lambda x: x.weekday())

# %%
df_BTC.head()
# Out:
#               open_time            close_time      open      high       low  \
# 0  05/24/2023, 23:00:00  05/24/2023, 23:59:59  26348.52  26394.16  26318.25
# 1  05/24/2023, 22:00:00  05/24/2023, 22:59:59  26368.66  26406.00  26313.47
# 2  05/24/2023, 21:00:00  05/24/2023, 21:59:59  26404.18  26464.65  26310.48
# 3  05/24/2023, 20:00:00  05/24/2023, 20:59:59  26252.34  26486.46  26242.62
# 4  05/24/2023, 19:00:00  05/24/2023, 19:59:59  26220.55  26397.64  26201.67
#
#       close      volume  quote_asset_volume  num_trades  \
# 0  26329.01   712.51394         18778933.16       16479
# 1  26348.52   746.24121         19670396.24       19907
# 2  26368.66  1223.45586         32298325.57       27225
# 3  26404.18  2878.77545         75937036.88       47336
# 4  26252.33  2349.96235         61795762.11       40509
#
#    taker_buy_base_asset_volume  taker_buy_quote_asset_volume  ignore  \
# 0                    376.83127                  9.932271e+06       0
# 1                    325.98884                  8.592227e+06       0
# 2                    642.68037                  1.696504e+07       0
# 3                   1539.53932                  4.060586e+07       0
# 4                   1171.28517                  3.080221e+07       0
#
#    open_timestamp  close_timestamp            datetime  year  month  day  \
# 0    1.684970e+12     1.684970e+12 2023-05-24 23:00:00  2023      5   24
# 1    1.684970e+12     1.684970e+12 2023-05-24 22:00:00  2023      5   24
# 2    1.684960e+12     1.684970e+12 2023-05-24 21:00:00  2023      5   24
# 3    1.684960e+12     1.684960e+12 2023-05-24 20:00:00  2023      5   24
# 4    1.684950e+12     1.684960e+12 2023-05-24 19:00:00  2023      5   24
#
#    day_of_week
# 0            2
# 1            2
# 2            2
# 3            2
# 4            2

# %%
df_BTC.dtypes
# Out:
# open_time                               object
# close_time                              object
# open                                   float64
# high                                   float64
# low                                    float64
# close                                  float64
# volume                                 float64
# quote_asset_volume                     float64
# num_trades                               int64
# taker_buy_base_asset_volume            float64
# taker_buy_quote_asset_volume           float64
# ignore                                   int64
# open_timestamp                         float64
# close_timestamp                        float64
# datetime                        datetime64[ns]
# year                                     int64
# month                                    int64
# day                                      int64
# day_of_week                              int64
# dtype: object

# %%
df_BTC = df_BTC.sort_values('datetime', ascending = True)

# %%
df_BTC['change_close'] = - (df_BTC['close'].shift(1) - df_BTC['close'])

# %%
df_BTC.head()
# Out:
#                   open_time            close_time      open      high  \
# 20961  01/01/2021, 00:00:00  01/01/2021, 00:59:59  28923.63  29031.34
# 20960  01/01/2021, 01:00:00  01/01/2021, 01:59:59  28995.13  29470.00
# 20959  01/01/2021, 02:00:00  01/01/2021, 02:59:59  29410.00  29465.26
# 20958  01/01/2021, 03:00:00  01/01/2021, 03:59:59  29195.25  29367.00
# 20957  01/01/2021, 04:00:00  01/01/2021, 04:59:59  29278.41  29395.00
#
#             low     close       volume  quote_asset_volume  num_trades  \
# 20961  28690.17  28995.13  2311.811445        6.676883e+07       58389
# 20960  28960.35  29409.99  5403.068471        1.583578e+08      103896
# 20959  29120.03  29194.65  2384.231560        6.984265e+07       57646
# 20958  29150.02  29278.40  1461.345077        4.276078e+07       42510
# 20957  29029.40  29220.31  2038.046803        5.961464e+07       55414
#
#        taker_buy_base_asset_volume  ...  ignore  open_timestamp  \
# 20961                  1215.359238  ...       0    1.609460e+12
# 20960                  3160.041701  ...       0    1.609460e+12
# 20959                  1203.433506  ...       0    1.609470e+12
# 20958                   775.915666  ...       0    1.609470e+12
# 20957                  1003.342834  ...       0    1.609470e+12
#
#        close_timestamp            datetime  year  month  day  day_of_week  \
# 20961     1.609460e+12 2021-01-01 00:00:00  2021      1    1            4
# 20960     1.609470e+12 2021-01-01 01:00:00  2021      1    1            4
# 20959     1.609470e+12 2021-01-01 02:00:00  2021      1    1            4
# 20958     1.609470e+12 2021-01-01 03:00:00  2021      1    1            4
# 20957     1.609480e+12 2021-01-01 04:00:00  2021      1    1            4
#
#        change_open  change_close
# 20961          NaN           NaN
# 20960        71.50        414.86
# 20959       414.87       -215.34
# 20958      -214.75         83.75
# 20957        83.16        -58.09
#
# [5 rows x 21 columns]

# %%
df_BTC = df_BTC.drop('ignore', axis =1)

# %%
df_BTC.tail()
# Out:
#               open_time            close_time      open      high       low  \
# 4  05/24/2023, 19:00:00  05/24/2023, 19:59:59  26220.55  26397.64  26201.67
# 3  05/24/2023, 20:00:00  05/24/2023, 20:59:59  26252.34  26486.46  26242.62
# 2  05/24/2023, 21:00:00  05/24/2023, 21:59:59  26404.18  26464.65  26310.48
# 1  05/24/2023, 22:00:00  05/24/2023, 22:59:59  26368.66  26406.00  26313.47
# 0  05/24/2023, 23:00:00  05/24/2023, 23:59:59  26348.52  26394.16  26318.25
#
#       close      volume  quote_asset_volume  num_trades  \
# 4  26252.33  2349.96235         61795762.11       40509
# 3  26404.18  2878.77545         75937036.88       47336
# 2  26368.66  1223.45586         32298325.57       27225
# 1  26348.52   746.24121         19670396.24       19907
# 0  26329.01   712.51394         18778933.16       16479
#
#    taker_buy_base_asset_volume  taker_buy_quote_asset_volume  open_timestamp  \
# 4                   1171.28517                  3.080221e+07    1.684950e+12
# 3                   1539.53932                  4.060586e+07    1.684960e+12
# 2                    642.68037                  1.696504e+07    1.684960e+12
# 1                    325.98884                  8.592227e+06    1.684970e+12
# 0                    376.83127                  9.932271e+06    1.684970e+12
#
#    close_timestamp            datetime  year  month  day  day_of_week  \
# 4     1.684960e+12 2023-05-24 19:00:00  2023      5   24            2
# 3     1.684960e+12 2023-05-24 20:00:00  2023      5   24            2
# 2     1.684970e+12 2023-05-24 21:00:00  2023      5   24            2
# 1     1.684970e+12 2023-05-24 22:00:00  2023      5   24            2
# 0     1.684970e+12 2023-05-24 23:00:00  2023      5   24            2
#
#    change_open  change_close
# 4       -64.46         31.78
# 3        31.79        151.85
# 2       151.84        -35.52
# 1       -35.52        -20.14
# 0       -20.14        -19.51

# %%
corr_matrix = df_BTC.corr()

# %%
# sn.heatmap(corr_matrix, annot=True)
# plt.show()

# %%
mask = np.zeros_like(corr_matrix)
mask[np.triu_indices_from(mask)] = True
with sn.axes_style("white"):
    f, ax = plt.subplots(figsize=(15, 11))
    ax = sn.heatmap(corr_matrix, mask=mask, vmax=1.0, vmin= -1.0, square=True, annot=True)
    bottom, top = ax.get_ylim()
    ax.set_ylim(bottom + 0.5, top - 0.5)
    
plt.show()

# %%
df_BTC_agg = pd.pivot_table(df_BTC, index=df_BTC.datetime.dt.week, columns=df_BTC.datetime.dt.year,
                    values='open', aggfunc='mean')

df_BTC_agg.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   """Entry point for launching an IPython kernel.
# datetime          2021          2022          2023
# datetime
# 1         36654.806071  43992.068690  16819.790357
# 2         36045.788929  42761.113571  18707.264881
# 3         33917.663333  39750.659226  21591.473512
# 4         32971.336964  36878.642202  22995.816548
# 5         36889.211786  38937.399583  23327.313452

# %%
df_BTC_agg1to6 = df_BTC_agg[df_BTC_agg.index <22]
df_BTC_agg1to6
# Out:
# datetime          2021          2022          2023
# datetime
# 1         36654.806071  43992.068690  16819.790357
# 2         36045.788929  42761.113571  18707.264881
# 3         33917.663333  39750.659226  21591.473512
# 4         32971.336964  36878.642202  22995.816548
# 5         36889.211786  38937.399583  23327.313452
# 6         46113.208024  43293.901012  22413.938512
# 7         52227.444583  41710.902321  23439.633393
# 8         48863.646131  38137.416964  23924.535357
# 9         48848.399760  41329.750000  23004.518095
# 10        56056.424940  39275.348750  21288.303512
# 11        57377.390238  40458.825476  25424.018333
# 12        54704.164048  43232.364643  27820.951737
# 13        58376.141369  46725.338750  27994.689048
# 14        58370.478929  44142.654702  28046.865476
# 15        61062.750714  40463.641964  30016.406845
# 16        52990.768405  40461.762381  28697.657798
# 17        55109.944286  38993.304821  28699.627024
# 18        56996.450714  37263.588274  28781.424762
# 19        52288.763512  30410.057083  27248.523333
# 20        39889.817619  29778.897262  27045.122619
# 21        37178.857083  29365.678512  26888.972639

# %%
df_BTC_agg1to6.plot(title='Average Open Price by week YoY', xlabel='Week of year')
plt.show()

# %%
df_BTC_close_agg = pd.pivot_table(df_BTC, index=df_BTC.datetime.dt.week, columns=df_BTC.datetime.dt.year,
                    values=['high','low'], aggfunc='mean')

df_BTC_closeagg_1to6 = df_BTC_close_agg[df_BTC_close_agg.index <22]
df_BTC_closeagg_1to6 


df_BTC_closeagg_1to6.plot(title='Average High Price by week YoY', xlabel='Week of year')
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   """Entry point for launching an IPython kernel.

# %%
df_BTC_vol_1to6.plot(title='Total Volumes of BTC by week YoY', xlabel='Week of year')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-03d0917c10cd> in <module>
# ----> 1 df_BTC_vol_1to6.plot(title='Total Volumes of BTC by week YoY', xlabel='Week of year')
#       2 plt.show()
#
# NameError: name 'df_BTC_vol_1to6' is not defined

# %%
df_BTC_trade = pd.pivot_table(df_BTC, index=df_BTC.datetime.dt.week, columns=df_BTC.datetime.dt.year,
                    values='num_trades', aggfunc='mean')

df_BTC_trade[df_BTC_trade.index <22].plot(title='Total Volumes of BTC by week YoY', xlabel='Week of year')
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   """Entry point for launching an IPython kernel.

# %%
#Volume to Trade Ratio

df_BTC['VolperTrade'] = df_BTC['volume']/df_BTC['num_trades']


df_volpertrade = pd.pivot_table(df_BTC, index=df_BTC.datetime.dt.week, columns=df_BTC.datetime.dt.year,
                    values='VolperTrade', aggfunc='sum')

df_volpertrade[df_volpertrade.index <22].plot(title='Volumes per trade of BTC by week YoY', xlabel='Week of year')
plt.show()



#2023 observing a decline in the purchasing behaviour as the months progress
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
df_BTC.head()
# Out:
#                   open_time            close_time      open      high  \
# 20961  01/01/2021, 00:00:00  01/01/2021, 00:59:59  28923.63  29031.34
# 20960  01/01/2021, 01:00:00  01/01/2021, 01:59:59  28995.13  29470.00
# 20959  01/01/2021, 02:00:00  01/01/2021, 02:59:59  29410.00  29465.26
# 20958  01/01/2021, 03:00:00  01/01/2021, 03:59:59  29195.25  29367.00
# 20957  01/01/2021, 04:00:00  01/01/2021, 04:59:59  29278.41  29395.00
#
#             low     close       volume  quote_asset_volume  num_trades  \
# 20961  28690.17  28995.13  2311.811445        6.676883e+07       58389
# 20960  28960.35  29409.99  5403.068471        1.583578e+08      103896
# 20959  29120.03  29194.65  2384.231560        6.984265e+07       57646
# 20958  29150.02  29278.40  1461.345077        4.276078e+07       42510
# 20957  29029.40  29220.31  2038.046803        5.961464e+07       55414
#
#        taker_buy_base_asset_volume  taker_buy_quote_asset_volume  \
# 20961                  1215.359238                   35103542.78
# 20960                  3160.041701                   92613991.94
# 20959                  1203.433506                   35252749.91
# 20958                   775.915666                   22705547.98
# 20957                  1003.342834                   29346381.88
#
#        open_timestamp  close_timestamp            datetime  year  month  day  \
# 20961    1.609460e+12     1.609460e+12 2021-01-01 00:00:00  2021      1    1
# 20960    1.609460e+12     1.609470e+12 2021-01-01 01:00:00  2021      1    1
# 20959    1.609470e+12     1.609470e+12 2021-01-01 02:00:00  2021      1    1
# 20958    1.609470e+12     1.609470e+12 2021-01-01 03:00:00  2021      1    1
# 20957    1.609470e+12     1.609480e+12 2021-01-01 04:00:00  2021      1    1
#
#        day_of_week  change_open  VolperTrade
# 20961            4          NaN     0.039593
# 20960            4        71.50     0.052005
# 20959            4       414.87     0.041360
# 20958            4      -214.75     0.034377
# 20957            4        83.16     0.036779

# %%
df_BTC.dtypes
# Out:
# open_time                               object
# close_time                              object
# open                                   float64
# high                                   float64
# low                                    float64
# close                                  float64
# volume                                 float64
# quote_asset_volume                     float64
# num_trades                               int64
# taker_buy_base_asset_volume            float64
# taker_buy_quote_asset_volume           float64
# open_timestamp                         float64
# close_timestamp                        float64
# datetime                        datetime64[ns]
# year                                     int64
# month                                    int64
# day                                      int64
# day_of_week                              int64
# change_open                            float64
# VolperTrade                            float64
# dtype: object

# %% [markdown]
# ### Load Twitter data

# %%
df_tweet = pd.read_csv('BTC_tweets_cleaned.csv')
df_tweet.head()
# Out:
#    year  month  day  day_of_week  \
# 0  2023      5   20            5
# 1  2023      5   20            5
# 2  2023      5   20            5
# 3  2023      5   20            5
# 4  2023      5   20            5
#
#                                                 text             timestamp  \
# 0  Today's Sophia BTC Mood: Bearish #Crypto #Cryp...  2023-05-20T00:00:00Z
# 1  App Development On Bitcoin?, Beeple Bitboy NFT...  2023-05-20T00:00:00Z
# 2  PREÇO BITCOIN BRASIL (BTCBRL)\nValor: R$ 134.8...  2023-05-20T00:00:00Z
# 3  $BTC Price: $26,875 \n#Bitcoin #BTC #BitcoinPr...  2023-05-20T00:00:00Z
# 4  #Bitcoin #Crypto #Blockchain #Cryptocurrency #...  2023-05-20T01:00:00Z
#
#   sentiment
# 0   NEUTRAL
# 1   NEUTRAL
# 2   NEUTRAL
# 3   NEUTRAL
# 4   NEUTRAL

# %%
df_tweet_senti = pd.get_dummies(df_tweet.sentiment, prefix='Sentiment')
# df_tweet_senti.shape
df_tweet = df_tweet.join(df_tweet_senti)
df_tweet.shape
# Out:
# (622, 10)

# %%
df_tweet_agg = df_tweet.groupby(['year','month','day']).agg({'Sentiment_NEGATIVE':'sum','Sentiment_NEUTRAL':'sum',
                                                            'Sentiment_POSITIVE':'sum'}).reset_index()

df_tweet_agg.head(2)
# Out:
#    year  month  day  Sentiment_NEGATIVE  Sentiment_NEUTRAL  Sentiment_POSITIVE
# 0  2023      5   20                   2                 97                   0
# 1  2023      5   21                   2                 82                   0

# %%
df_tweet_agg.shape
# Out:
# (5, 6)

# %%
df_BTC.shape
# Out:
# (20962, 20)

# %%
df_joined = pd.merge(df_BTC, df_tweet_agg, how='left', on=['year','month','day'])

df_joined.shape
# Out:
# (20962, 23)

# %%
df_joined.head(2)
# Out:
#               open_time            close_time      open      high       low  \
# 0  01/01/2021, 00:00:00  01/01/2021, 00:59:59  28923.63  29031.34  28690.17
# 1  01/01/2021, 01:00:00  01/01/2021, 01:59:59  28995.13  29470.00  28960.35
#
#       close       volume  quote_asset_volume  num_trades  \
# 0  28995.13  2311.811445        6.676883e+07       58389
# 1  29409.99  5403.068471        1.583578e+08      103896
#
#    taker_buy_base_asset_volume  ...            datetime  year  month day  \
# 0                  1215.359238  ... 2021-01-01 00:00:00  2021      1   1
# 1                  3160.041701  ... 2021-01-01 01:00:00  2021      1   1
#
#    day_of_week  change_open  VolperTrade  Sentiment_NEGATIVE  \
# 0            4          NaN     0.039593                 NaN
# 1            4         71.5     0.052005                 NaN
#
#    Sentiment_NEUTRAL  Sentiment_POSITIVE
# 0                NaN                 NaN
# 1                NaN                 NaN
#
# [2 rows x 23 columns]

# %%
#filter for the days twitter data is avialable
df_filter = df_joined[df_joined['datetime'] >= datetime.datetime(2023, 5, 20)]

# %%
df_filter.dtypes
# Out:
# open_time                               object
# close_time                              object
# open                                   float64
# high                                   float64
# low                                    float64
# close                                  float64
# volume                                 float64
# quote_asset_volume                     float64
# num_trades                               int64
# taker_buy_base_asset_volume            float64
# taker_buy_quote_asset_volume           float64
# open_timestamp                         float64
# close_timestamp                        float64
# datetime                        datetime64[ns]
# year                                     int64
# month                                    int64
# day                                      int64
# day_of_week                              int64
# change_open                            float64
# VolperTrade                            float64
# Sentiment_NEGATIVE                     float64
# Sentiment_NEUTRAL                      float64
# Sentiment_POSITIVE                     float64
# dtype: object

# %%
#Aggregating the dataframe by day to find out any correlation between the tweets and the prices 

df_daily = df_filter.groupby(['day','month','year','day_of_week']).agg({'open_time':'min',
                                                                         'close_time':'max',
                                                                         'open':'first',
                                                                         'high':'max',
                                                                         'low':'min',
                                                                         'close':'last',
                                                                         'volume':'sum',
                                                                         'num_trades':'sum',
                                                                         'open_timestamp':'min',
                                                                         'close_timestamp':'max',
                                                                         'Sentiment_NEGATIVE':'mean',
                                                                         'Sentiment_NEUTRAL':'mean',
                                                                         'Sentiment_POSITIVE':'mean'}).reset_index()


df_daily['VolperTrade'] = df_daily['volume']/df_daily['num_trades']
df_daily.head()
# Out:
#    day  month  year  day_of_week             open_time            close_time  \
# 0   20      5  2023            5  05/20/2023, 00:00:00  05/20/2023, 23:59:59
# 1   21      5  2023            6  05/21/2023, 00:00:00  05/21/2023, 23:59:59
# 2   22      5  2023            0  05/22/2023, 00:00:00  05/22/2023, 23:59:59
# 3   23      5  2023            1  05/23/2023, 00:00:00  05/23/2023, 23:59:59
# 4   24      5  2023            2  05/24/2023, 00:00:00  05/24/2023, 23:59:59
#
#        open      high       low     close       volume  num_trades  \
# 0  26880.26  27150.00  26825.11  27102.43  14434.54718      481382
# 1  27102.42  27277.55  26666.03  26747.78  21347.87279      568937
# 2  26747.78  27099.89  26538.21  26849.27  26458.83828      717111
# 3  26849.28  27495.83  26798.11  27219.61  38700.83858      816399
# 4  27219.61  27219.61  26080.50  26329.01  54393.06570     1012767
#
#    open_timestamp  close_timestamp  Sentiment_NEGATIVE  Sentiment_NEUTRAL  \
# 0    1.684540e+12     1.684630e+12                 2.0               97.0
# 1    1.684630e+12     1.684710e+12                 2.0               82.0
# 2    1.684710e+12     1.684800e+12                 0.0              150.0
# 3    1.684800e+12     1.684890e+12                 0.0              126.0
# 4    1.684890e+12     1.684970e+12                 1.0              159.0
#
#    Sentiment_POSITIVE  VolperTrade
# 0                 0.0     0.029986
# 1                 0.0     0.037522
# 2                 1.0     0.036896
# 3                 2.0     0.047404
# 4                 0.0     0.053707

# %%
df_daily.columns
# Out:
# Index(['day', 'month', 'year', 'day_of_week', 'open_time', 'close_time',
#        'open', 'high', 'low', 'close', 'volume', 'num_trades',
#        'open_timestamp', 'close_timestamp', 'Sentiment_NEGATIVE',
#        'Sentiment_NEUTRAL', 'Sentiment_POSITIVE', 'VolperTrade'],
#       dtype='object')

# %%
corr = df_daily[['day_of_week', 'open_time', 'close_time',
               'open', 'high', 'low', 'close', 'volume', 'num_trades',
               'open_timestamp', 'close_timestamp', 'Sentiment_NEGATIVE',
               'Sentiment_NEUTRAL', 'Sentiment_POSITIVE', 'VolperTrade']].corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sn.axes_style("white"):
    f, ax = plt.subplots(figsize=(12, 9))
    ax = sn.heatmap(corr, mask=mask, vmax=1.0, vmin= -1.0, square=True, annot=True)
    bottom, top = ax.get_ylim()
    ax.set_ylim(bottom + 0.5, top - 0.5)
    
plt.show()
