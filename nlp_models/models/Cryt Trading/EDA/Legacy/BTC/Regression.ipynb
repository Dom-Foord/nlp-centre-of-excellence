# %%
import pandas as pd
import boto3
import json
import datetime

# %% [markdown]
# ### Getting Tweets

# %%
df_tweets = pd.read_csv("BTC_tweets.csv")

# %%
df_tweets = df_tweets.drop('Unnamed: 0', axis=1)

# %%
df_tweets
# Out:
#                                                   text             timestamp
# 0    Today's Sophia BTC Mood: Bearish #Crypto #Cryp...  2023-05-20T00:00:00Z
# 1    App Development On Bitcoin?, Beeple Bitboy NFT...  2023-05-20T00:00:00Z
# 2    PREÇO BITCOIN BRASIL (BTCBRL)\nValor: R$ 134.8...  2023-05-20T00:00:00Z
# 3    $BTC Price: $26,875 \n#Bitcoin #BTC #BitcoinPr...  2023-05-20T00:00:00Z
# 4    #Bitcoin #Crypto #Blockchain #Cryptocurrency #...  2023-05-20T01:00:00Z
# ..                                                 ...                   ...
# 617  RT @darkducktrader: 🛰 SpaceX will deliver a pr...  2023-05-24T23:00:00Z
# 618  #Bitcoin #Crypto #Blockchain #Cryptocurrency #...  2023-05-24T23:00:00Z
# 619  #Bitcoin #Crypto #Blockchain #Cryptocurrency #...  2023-05-24T23:00:00Z
# 620  #Bitcoin #Crypto #Blockchain #Cryptocurrency #...  2023-05-24T23:00:00Z
# 621  $BTC Price: $26,351 \n#Bitcoin #BTC #BitcoinPr...  2023-05-24T23:00:00Z
#
# [622 rows x 2 columns]

# %% [markdown]
# #### Running Comprehend

# %%
comprehend = boto3.client(service_name='comprehend', region_name='eu-west-1')

# %%
df_tweets['sentiment'] = df_tweets['text'].apply(lambda x: json.loads(json.dumps(comprehend.detect_sentiment(Text=x, LanguageCode='en'), sort_keys=True, indent=4))['Sentiment'])

# %%
df_tweets
# Out:
#                                                   text             timestamp  \
# 0    Today's Sophia BTC Mood: Bearish #Crypto #Cryp...  2023-05-20T00:00:00Z
# 1    App Development On Bitcoin?, Beeple Bitboy NFT...  2023-05-20T00:00:00Z
# 2    PREÇO BITCOIN BRASIL (BTCBRL)\nValor: R$ 134.8...  2023-05-20T00:00:00Z
# 3    $BTC Price: $26,875 \n#Bitcoin #BTC #BitcoinPr...  2023-05-20T00:00:00Z
# 4    #Bitcoin #Crypto #Blockchain #Cryptocurrency #...  2023-05-20T01:00:00Z
# ..                                                 ...                   ...
# 617  RT @darkducktrader: 🛰 SpaceX will deliver a pr...  2023-05-24T23:00:00Z
# 618  #Bitcoin #Crypto #Blockchain #Cryptocurrency #...  2023-05-24T23:00:00Z
# 619  #Bitcoin #Crypto #Blockchain #Cryptocurrency #...  2023-05-24T23:00:00Z
# 620  #Bitcoin #Crypto #Blockchain #Cryptocurrency #...  2023-05-24T23:00:00Z
# 621  $BTC Price: $26,351 \n#Bitcoin #BTC #BitcoinPr...  2023-05-24T23:00:00Z
#
#     sentiment
# 0     NEUTRAL
# 1     NEUTRAL
# 2     NEUTRAL
# 3     NEUTRAL
# 4     NEUTRAL
# ..        ...
# 617   NEUTRAL
# 618   NEUTRAL
# 619   NEUTRAL
# 620   NEUTRAL
# 621   NEUTRAL
#
# [622 rows x 3 columns]

# %%
df_tweets['year'] = df_tweets['timestamp'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%SZ").year)
df_tweets['month'] = df_tweets['timestamp'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%SZ").month)
df_tweets['day'] = df_tweets['timestamp'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%SZ").day)
df_tweets['day_of_week'] = df_tweets['timestamp'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%SZ").weekday())

# %%
cols = list(df_tweets.columns)[3:] + list(df_tweets.columns)[:3]

# %%
cols
# Out:
# ['year', 'month', 'day', 'day_of_week', 'text', 'timestamp', 'sentiment']

# %%
df_tweets = df_tweets[cols]

# %%
df_tweets.to_csv('BTC_tweets_cleaned.csv', index=False)

# %% [markdown]
# ### Aggregating for Regression

# %%
df_tweets_agg = pd.DataFrame(df_tweets.groupby('timestamp')['sentiment'].agg(pd.Series.mode)).reset_index()

# %%
df_tweets_agg = df_tweets.rename(columns = {'timestamp': 'open_time'})

# %%
df_tweets_agg.head()
# Out:
#               open_time sentiment
# 0  2023-05-20T00:00:00Z   NEUTRAL
# 1  2023-05-20T01:00:00Z   NEUTRAL
# 2  2023-05-20T02:00:00Z   NEUTRAL
# 3  2023-05-20T03:00:00Z   NEUTRAL
# 4  2023-05-20T04:00:00Z   NEUTRAL

# %% [markdown]
# #### Importing Bitcoin price data

# %%
df_btc = pd.read_csv("BTC_USDT_20230519_20230525_128.csv")

# %%
df_btc.head()
# Out:
#               open_time            close_time      open      high       low  \
# 0  05/24/2023, 23:00:00  05/24/2023, 23:59:59  26348.52  26394.16  26318.25
# 1  05/24/2023, 22:00:00  05/24/2023, 22:59:59  26368.66  26406.00  26313.47
# 2  05/24/2023, 21:00:00  05/24/2023, 21:59:59  26404.18  26464.65  26310.48
# 3  05/24/2023, 20:00:00  05/24/2023, 20:59:59  26252.34  26486.46  26242.62
# 4  05/24/2023, 19:00:00  05/24/2023, 19:59:59  26220.55  26397.64  26201.67
#
#       close      volume  quote_asset_volume  num_trades  \
# 0  26329.01   712.51394        1.877893e+07       16479
# 1  26348.52   746.24121        1.967040e+07       19907
# 2  26368.66  1223.45586        3.229833e+07       27225
# 3  26404.18  2878.77545        7.593704e+07       47336
# 4  26252.33  2349.96235        6.179576e+07       40509
#
#    taker_buy_base_asset_volume  taker_buy_quote_asset_volume  ignore  \
# 0                    376.83127                  9.932271e+06       0
# 1                    325.98884                  8.592227e+06       0
# 2                    642.68037                  1.696504e+07       0
# 3                   1539.53932                  4.060586e+07       0
# 4                   1171.28517                  3.080221e+07       0
#
#    open_timestamp  close_timestamp
# 0   1684969200000    1684972799999
# 1   1684965600000    1684969199999
# 2   1684962000000    1684965599999
# 3   1684958400000    1684961999999
# 4   1684954800000    1684958399999

# %%
df_btc['open_time'] = df_btc['open_time'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y, %H:%M:%S").isoformat() +'Z')

# %%
df_btc.join(df_tweets.set_index('open_time'), on = "open_time", how = "inner")
# Out:
#                 open_time            close_time      open      high       low  \
# 0    2023-05-24T23:00:00Z  05/24/2023, 23:59:59  26348.52  26394.16  26318.25
# 1    2023-05-24T22:00:00Z  05/24/2023, 22:59:59  26368.66  26406.00  26313.47
# 2    2023-05-24T21:00:00Z  05/24/2023, 21:59:59  26404.18  26464.65  26310.48
# 3    2023-05-24T20:00:00Z  05/24/2023, 20:59:59  26252.34  26486.46  26242.62
# 4    2023-05-24T19:00:00Z  05/24/2023, 19:59:59  26220.55  26397.64  26201.67
# ..                    ...                   ...       ...       ...       ...
# 115  2023-05-20T04:00:00Z  05/20/2023, 04:59:59  26865.59  26873.63  26851.11
# 116  2023-05-20T03:00:00Z  05/20/2023, 03:59:59  26839.63  26874.74  26839.62
# 117  2023-05-20T02:00:00Z  05/20/2023, 02:59:59  26858.98  26870.05  26832.36
# 118  2023-05-20T01:00:00Z  05/20/2023, 01:59:59  26845.71  26885.86  26845.54
# 119  2023-05-20T00:00:00Z  05/20/2023, 00:59:59  26880.26  26908.42  26825.11
#
#         close      volume  quote_asset_volume  num_trades  \
# 0    26329.01   712.51394        1.877893e+07       16479
# 1    26348.52   746.24121        1.967040e+07       19907
# 2    26368.66  1223.45586        3.229833e+07       27225
# 3    26404.18  2878.77545        7.593704e+07       47336
# 4    26252.33  2349.96235        6.179576e+07       40509
# ..        ...         ...                 ...         ...
# 115  26873.63   337.53628        9.066916e+06       15527
# 116  26865.58   318.51343        8.554464e+06       16334
# 117  26839.63   327.99884        8.807418e+06       12311
# 118  26858.98   270.63860        7.269188e+06       14041
# 119  26845.71   564.98609        1.517702e+07       24339
#
#      taker_buy_base_asset_volume  taker_buy_quote_asset_volume  ignore  \
# 0                      376.83127                  9.932271e+06       0
# 1                      325.98884                  8.592227e+06       0
# 2                      642.68037                  1.696504e+07       0
# 3                     1539.53932                  4.060586e+07       0
# 4                     1171.28517                  3.080221e+07       0
# ..                           ...                           ...     ...
# 115                    147.76932                  3.969283e+06       0
# 116                    171.26475                  4.599587e+06       0
# 117                    138.35650                  3.715217e+06       0
# 118                    137.13224                  3.683199e+06       0
# 119                    257.26718                  6.910766e+06       0
#
#      open_timestamp  close_timestamp sentiment
# 0     1684969200000    1684972799999   NEUTRAL
# 1     1684965600000    1684969199999   NEUTRAL
# 2     1684962000000    1684965599999   NEUTRAL
# 3     1684958400000    1684961999999   NEUTRAL
# 4     1684954800000    1684958399999   NEUTRAL
# ..              ...              ...       ...
# 115   1684555200000    1684558799999   NEUTRAL
# 116   1684551600000    1684555199999   NEUTRAL
# 117   1684548000000    1684551599999   NEUTRAL
# 118   1684544400000    1684547999999   NEUTRAL
# 119   1684540800000    1684544399999   NEUTRAL
#
# [120 rows x 15 columns]
